# %% [markdown]
# # Exporting the libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Cleaning the data

# %%
data = pd.read_csv('breastCancer.csv')
data.head()
# Out:
#         id  clump_thickness  size_uniformity  shape_uniformity  \
# 0  1000025                5                1                 1
# 1  1002945                5                4                 4
# 2  1015425                3                1                 1
# 3  1016277                6                8                 8
# 4  1017023                4                1                 1
#
#    marginal_adhesion  epithelial_size bare_nucleoli  bland_chromatin  \
# 0                  1                2             1                3
# 1                  5                7            10                3
# 2                  1                2             2                3
# 3                  1                3             4                3
# 4                  3                2             1                3
#
#    normal_nucleoli  mitoses  class
# 0                1        1      2
# 1                2        1      2
# 2                1        1      2
# ...

# %%
data.isnull().sum()
# Out:
# id                   0
# clump_thickness      0
# size_uniformity      0
# shape_uniformity     0
# marginal_adhesion    0
# epithelial_size      0
# bare_nucleoli        0
# bland_chromatin      0
# normal_nucleoli      0
# mitoses              0
# class                0
# dtype: int64

# %%
data.dtypes
# Out:
# id                    int64
# clump_thickness       int64
# size_uniformity       int64
# shape_uniformity      int64
# marginal_adhesion     int64
# epithelial_size       int64
# bare_nucleoli        object
# bland_chromatin       int64
# normal_nucleoli       int64
# mitoses               int64
# class                 int64
# dtype: object

# %%
data['bare_nucleoli'].value_counts()
# Out:
# 1     402
# 10    132
# 2      30
# 5      30
# 3      28
# 8      21
# 4      19
# ?      16
# 9       9
# 7       8
# 6       4
# Name: bare_nucleoli, dtype: int64

# %%
data[data['bare_nucleoli'] == '?']
# Out:
#           id  clump_thickness  size_uniformity  shape_uniformity  \
# 23   1057013                8                4                 5
# 40   1096800                6                6                 6
# 139  1183246                1                1                 1
# 145  1184840                1                1                 3
# 158  1193683                1                1                 2
# 164  1197510                5                1                 1
# 235  1241232                3                1                 4
# 249   169356                3                1                 1
# 275   432809                3                1                 3
# 292   563649                8                8                 8
# 294   606140                1                1                 1
# 297    61634                5                4                 3
# 315   704168                4                6                 5
# ...

# %%
for i in range(len(data.iloc[:,6])):
    if data['bare_nucleoli'][i] == '?':
        data['bare_nucleoli'][i] = data['bare_nucleoli'].median()

data.head(30)
# Out:
#          id  clump_thickness  size_uniformity  shape_uniformity  \
# 0   1000025                5                1                 1
# 1   1002945                5                4                 4
# 2   1015425                3                1                 1
# 3   1016277                6                8                 8
# 4   1017023                4                1                 1
# 5   1017122                8               10                10
# 6   1018099                1                1                 1
# 7   1018561                2                1                 2
# 8   1033078                2                1                 1
# 9   1033078                4                2                 1
# 10  1035283                1                1                 1
# 11  1036172                2                1                 1
# 12  1041801                5                3                 3
# 13  1043999                1                1                 1
# ...

# %%
data.dtypes
# Out:
# id                    int64
# clump_thickness       int64
# size_uniformity       int64
# shape_uniformity      int64
# marginal_adhesion     int64
# epithelial_size       int64
# bare_nucleoli        object
# bland_chromatin       int64
# normal_nucleoli       int64
# mitoses               int64
# class                 int64
# dtype: object

# %%
data['bare_nucleoli'] = data['bare_nucleoli'].astype('int64')

# %%
data.dtypes
# Out:
# id                   int64
# clump_thickness      int64
# size_uniformity      int64
# shape_uniformity     int64
# marginal_adhesion    int64
# epithelial_size      int64
# bare_nucleoli        int64
# bland_chromatin      int64
# normal_nucleoli      int64
# mitoses              int64
# class                int64
# dtype: object

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.head()
# Out:
#         id  clump_thickness  size_uniformity  shape_uniformity  \
# 0  1000025                5                1                 1
# 1  1002945                5                4                 4
# 2  1015425                3                1                 1
# 3  1016277                6                8                 8
# 4  1017023                4                1                 1
#
#    marginal_adhesion  epithelial_size  bare_nucleoli  bland_chromatin  \
# 0                  1                2              1                3
# 1                  5                7             10                3
# 2                  1                2              2                3
# 3                  1                3              4                3
# 4                  3                2              1                3
#
#    normal_nucleoli  mitoses  class
# 0                1        1      2
# 1                2        1      2
# 2                1        1      2
# ...

# %%
data.shape
# Out:
# (699, 11)

# %%
data.columns
# Out:
# Index(['id', 'clump_thickness', 'size_uniformity', 'shape_uniformity',
#        'marginal_adhesion', 'epithelial_size', 'bare_nucleoli',
#        'bland_chromatin', 'normal_nucleoli', 'mitoses', 'class'],
#       dtype='object')

# %%
data.drop('id', axis = 1, inplace = True)

# %%
data.head()
# Out:
#    clump_thickness  size_uniformity  shape_uniformity  marginal_adhesion  \
# 0                5                1                 1                  1
# 1                5                4                 4                  5
# 2                3                1                 1                  1
# 3                6                8                 8                  1
# 4                4                1                 1                  3
#
#    epithelial_size  bare_nucleoli  bland_chromatin  normal_nucleoli  mitoses  \
# 0                2              1                3                1        1
# 1                7             10                3                2        1
# 2                2              2                3                1        1
# 3                3              4                3                7        1
# 4                2              1                3                1        1
#
#    class
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2

# %%
data.describe()
# Out:
#        clump_thickness  size_uniformity  shape_uniformity  marginal_adhesion  \
# count       699.000000       699.000000        699.000000         699.000000
# mean          4.417740         3.134478          3.207439           2.806867
# std           2.815741         3.051459          2.971913           2.855379
# min           1.000000         1.000000          1.000000           1.000000
# 25%           2.000000         1.000000          1.000000           1.000000
# 50%           4.000000         1.000000          1.000000           1.000000
# 75%           6.000000         5.000000          5.000000           4.000000
# max          10.000000        10.000000         10.000000          10.000000
#
#        epithelial_size  bare_nucleoli  bland_chromatin  normal_nucleoli  \
# count       699.000000     699.000000       699.000000       699.000000
# mean          3.216023       3.486409         3.437768         2.866953
# ...

# %%
data.hist(bins = 30,layout = (6,3), figsize = (30,30));

# %%
plt.figure(figsize = (15,15))
sns.boxplot(data = data, orient = 'h')

#plt.figure(figsize= (15,10))
#sns.boxplot(data=df,orient="h")
# Out:
# <AxesSubplot:>

# %%
corr = data.corr()
plt.figure(figsize = (15,15))
sns.heatmap(corr, annot = True, cmap = 'inferno')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Separating data into train and test

# %%
from sklearn.model_selection import train_test_split

X = data.drop('class', axis = 1)
y = data['class']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.3, random_state = 1)

# %% [markdown]
# # Building the KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
data.head()
# Out:
#    clump_thickness  size_uniformity  shape_uniformity  marginal_adhesion  \
# 0                5                1                 1                  1
# 1                5                4                 4                  5
# 2                3                1                 1                  1
# 3                6                8                 8                  1
# 4                4                1                 1                  3
#
#    epithelial_size  bare_nucleoli  bland_chromatin  normal_nucleoli  mitoses  \
# 0                2              1                3                1        1
# 1                7             10                3                2        1
# 2                2              2                3                1        1
# 3                3              4                3                7        1
# 4                2              1                3                1        1
#
#    class
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2

# %% [markdown]
# ### Finding the best k

# %%
scores = []

for i in range(3,20):
    KNN = KNeighborsClassifier(n_neighbors = i, weights = 'distance')
    KNN.fit(X_train,y_train)
    scores.append(KNN.score(X_test,y_test))
scores
# Out:
# [0.9714285714285714,
#  0.9809523809523809,
#  0.9714285714285714,
#  0.9761904761904762,
#  0.9666666666666667,
#  0.9761904761904762,
#  0.9619047619047619,
#  0.9666666666666667,
#  0.9666666666666667,
#  0.9666666666666667,
#  0.9666666666666667,
#  0.9619047619047619,
#  0.9619047619047619,
#  0.9619047619047619,
#  0.9619047619047619,
#  0.9523809523809523,
#  0.9619047619047619]

# %%
plt.figure(figsize = (10,10))
plt.plot(range(3,20),scores, linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)

# %% [markdown]
# ### The best k is 4,which gives us 98% accuracy.

# %%
KNN = KNeighborsClassifier(n_neighbors = 4, weights = 'distance')
KNN.fit(X_train,y_train)

KNN_predict = KNN.predict(X_test)
print("The accuracy of my KNN model is: {0:.4g}%".format(KNN.score(X_test,y_test) * 100 ))
# Out:
# The accuracy of my KNN model is: 98.1%

# %% [markdown]
# # Building the SVM Model

# %%
from sklearn.svm import SVC
SVM = SVC(gamma = 0.025, C = 3)
SVM.fit(X_train,y_train)

SVM_predict = KNN.predict(X_test)
print("The accuracy of my SVM model is: {0:.4g}%".format(SVM.score(X_test,y_test) * 100 ))
# Out:
# The accuracy of my SVM model is: 98.1%

# %% [markdown]
# # KNN model accuracy: 98.1%
# # SVM model accuracy: 98.1%

# %% [markdown]
# # Comparing the two models

# %%
pred1 = pd.DataFrame(KNN_predict)
pred2 = pd.DataFrame(SVM_predict)
ModelPredictions = pd.concat([pred1,pred2], axis = 1)
ModelPredictions.columns=[['KNN Predictions','SVM Predictions']]
ModelPredictions.head()
# Out:
#   KNN Predictions SVM Predictions
# 0               2               2
# 1               2               2
# 2               2               2
# 3               4               4
# 4               2               2

# %%
from sklearn.metrics import classification_report

# %%
print("KNN classification report")
print("..." * 10)
reportKNN = classification_report(y_test, pred1)
print(reportKNN)
# Out:
# KNN classification report
# ..............................
#               precision    recall  f1-score   support
#
#            2       0.98      0.99      0.99       137
#            4       0.99      0.96      0.97        73
#
#     accuracy                           0.98       210
#    macro avg       0.98      0.98      0.98       210
# weighted avg       0.98      0.98      0.98       210

# %%
print("SVM classification report")
print("..." * 10)
reportSVM = classification_report(y_test, pred2)
print(reportSVM)
# Out:
# SVM classification report
# ..............................
#               precision    recall  f1-score   support
#
#            2       0.98      0.99      0.99       137
#            4       0.99      0.96      0.97        73
#
#     accuracy                           0.98       210
#    macro avg       0.98      0.98      0.98       210
# weighted avg       0.98      0.98      0.98       210

# %% [markdown]
# ## It seems, our two models perform exactly the same

# %%
from sklearn.metrics import confusion_matrix

matrix_KNN = confusion_matrix(KNN_predict,y_test)
matrix = pd.DataFrame(matrix_KNN)
plt.figure(figsize = (15,15))
Visualization = sns.heatmap(matrix, annot = True, cmap = 'inferno')

# %%
matrix_SVM = confusion_matrix(SVM_predict,y_test)
matrix = pd.DataFrame(matrix_SVM)
plt.figure(figsize = (15,15))
Visualization = sns.heatmap(matrix, annot = True, cmap = 'inferno')

# %% [markdown]
# # Conclusion: Both the KNN model and the SVM model offer 98.1% accuracy, which means they perform equally well.
